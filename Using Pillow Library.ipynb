# %%
# pip install pillow

# %%
from PIL import Image

# %%
im  = Image.open('cat_or_dog_1.jpg')

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
im.show()

# %%
im.crop((100,100,  300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x291FDA49DF0>

# %%
im.rotate(45  , expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1188x1188 at 0x291FDC83B80>

# %%
im.resize((200,200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x291FCB3BB20>

# %%
Image.ROTATE_90
# Out:
# 2

# %%
im.transpose( Image.ROTATE_90 ).resize( ( 100,100) ).save('nnnn.png')

# %%
im.size
# Out:
# (960, 720)

# %%
im.height
# Out:
# 720

# %%
im.width
# Out:
# 960

# %%
im.format
# Out:
# 'JPEG'

# %%
from keras.preprocessing import image

# %%
kim = image.load_img('cat_or_dog_1.jpg' ,target_size=(100,100) )

# %%
type(kim)
# Out:
# PIL.Image.Image

# %%
kim.size
# Out:
# (100, 100)

# %%
kim
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x291FDC83D00>
